# %%
import pandas as pd

# %%
langs = pd.read_csv('cldf/languages.csv')
langs.head(10)
# Out:
#          ID           Name      Macroarea   Latitude   Longitude Glottocode  \
# 0  abkh1242   Abkhaz-Adyge        Eurasia  43.692403   40.870153   abkh1242
# 1  surm1244         Surmic         Africa   6.881999   34.973383   surm1244
# 2  tama1329         Tamaic         Africa  14.119900   22.072200   tama1329
# 3  yare1250        Yareban      Papunesia  -9.526501  148.413750   yare1250
# 4  monu1249          Bogia      Papunesia  -4.313245  144.970000   monu1249
# 5  tebe1251        Teberan      Papunesia  -6.760430  144.484500   tebe1251
# 6  sali1297        Saliban  South America   4.895613  -68.276825   sali1297
# 7  hibi1242  Hibito-Cholon  South America  -7.907310  -76.831050   hibi1242
# 8  kiwa1251        Kiwaian      Papunesia  -7.957872  143.851669   kiwa1251
# 9  paho1240       Pahoturi      Papunesia  -8.922485  142.416500   paho1240
#
#   ISO639P3code   Level Countries Family_ID Language_ID Closest_ISO369P3code  \
# ...
